# %%
# !pip install pandas numpy matplotlib seaborn scikit-learn graphviz
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import pandas as pd

# %%
dataset = pd.read_csv('Iris.csv')
dataset.drop('Id', axis=1, inplace=True)

# %%
dataset.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
print(dataset.isnull().sum())
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
dataset['Species'] = le.fit_transform(dataset['Species'])
X = dataset.drop('Species', axis=1)
y = dataset['Species']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
classification = DecisionTreeClassifier(criterion='gini',max_depth=3,random_state=42)
classification.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %%
Y_pred = classification.predict(x_test)
accuracy = accuracy_score(y_test, Y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9666666666666667

# %%
le.classes_
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
import matplotlib.pyplot as plt
from sklearn import tree
plt.figure(figsize=(12,8))
tree.plot_tree(classification, filled=True, feature_names=X.columns, class_names=[str(c) for c in le.classes_])
plt.show()

# %%
# single_data = [[5.1, 3.5, 1.4, 0.2]]
# predicted_class = classification.predict(single_data)
# print("Predicted class for single data point:", le.inverse_transform(predicted_class))

# Fixed Cell 11
single_data = [[4.1, 2.3, 106, 0.4]]
predicted_class = classification.predict(single_data)

# Ensure we get the name from the LabelEncoder
species_name = le.inverse_transform(predicted_class)
print("Predicted class for single data point:", species_name[0])
# Out:
# Predicted class for single data point: Iris-virginica
# c:\Users\DELL\Desktop\mashine learning\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
feat_importances = pd.Series(classification.feature_importances_, index=X.columns)
feat_importances.sort_values().plot(kind='barh')
plt.show()

# %%
# !pip install joblib
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import joblib

# Save the model
joblib.dump(classification, 'iris_model.pkl')

# Save the label encoder
joblib.dump(le, 'label_encoder.pkl')

print("Success! Download these files from your folder to upload to GitHub.")
# Out:
# Success! Download these files from your folder to upload to GitHub.
